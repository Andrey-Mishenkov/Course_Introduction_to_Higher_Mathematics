# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import factorial
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ### 1. Задание
# Напишите код, моделирующий выпадение поля в рулетке (с учетом поля зеро).

# %%
for i in range(0, 30):
#     a = input()
    x = np.random.randint(0, 37)
    
    if x == 0:
        print("zero")
    else:
        print(f'{x}')
# Out:
# 9
# 12
# 34
# 5
# 27
# 16
# 20
# 16
# 19
# 28
# 28
# 36
# 22
# 6
# 28
# 1
# 5
# 13
# 4
# 5
# 33
# 19
# 23
# 36
# 3
# 33
# 7
# 18
# 10
# 7

# %% [markdown]
# ### 2. Задание

# %% [markdown]
# #### 1. Напишите код, проверяющий любую из теорем сложения или умножения вероятности на примере рулетки или подбрасывания монетки.

# %% [markdown]
# Для независимых событий P(AB) = P(A) * P(B)
#
# На примере монеты:
# * Событие A - выпадение орла;  P(A) = 0.5
# * Событие B - выпадение решки; P(B) = 0.5
#
# Какова вероятность выпадения сначала орла, а затем решки?

# %%
p_A = 0.5
p_B = 0.5
print(f'P(AB) = P(A) * P(B) = {p_A * p_B}')
# Out:
# P(AB) = P(A) * P(B) = 0.25

# %% [markdown]
# #### 2. Сгенерируйте десять выборок случайных чисел х0, …, х9. И постройте гистограмму распределения случайной суммы х0+х1+ …+ х9.

# %%
s = []
for i in range(10):
    x = np.random.rand(10)
    s.append(x.sum())
print(s)

num_bins = 10
n, bins, patches = plt.hist(s, num_bins)
plt.xlabel('s')
plt.ylabel('Probability')
plt.title('Histogram')
# Out:
# [3.8864291343991177, 5.009884375424968, 6.183106742028, 5.37606638546607, 5.9508727645831625, 3.9720272163184243, 6.020560363831209, 4.482413344570827, 4.505834341838325, 4.640831234780772]
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# ### 3. Задание

# %% [markdown]
# #### 1. Дополните код Монте-Карло последовательности независимых испытаний расчетом соответствующих вероятностей (через биномиальное распределение) и сравните результаты.

# %%
def combinations(k, n):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

def bernulli(k, n, p):
    return combinations(k, n) * p**k * (1 - p)**(n-k)

def arrangements(k, n):
    return int(factorial(n) / factorial(n - k))

def permutations(n):
    return int(factorial(n))

# %%
k, n = 0, 10000
a = np.random.randint(0, 2, n)
b = np.random.randint(0, 2, n)
c = np.random.randint(0, 2, n)
d = np.random.randint(0, 2, n)
x = a + b + c + d
for i in range(0, n):
    if x[i] == 2:
        k = k + 1
#print(a, b, c, d)
#print(x)
print(k, n, k/n)
# Out:
# 3734 10000 0.3734

# %%
# формула Бернулли (биномиальное распределение)
p = bernulli(2, 4, 0.5)

print(f'Вероятность выпадения 2-х удачных исходов из 4-х по формуле Бернулли = {p}\nи совпадает с предыдущим результатом')
# Out:
# Вероятность выпадения 2-х удачных исходов из 4-х по формуле Бернулли = 0.375
# и совпадает с предыдущим результатом

# %% [markdown]
# #### 2. Повторите расчеты биномиальных коэффициентов и вероятностей k успехов в последовательности из n независимых испытаний, взяв другие значения n и k

# %%
print('Вероятность выпадения комбинаций:')

print(f'\t  3 успехов из  9 = {round(bernulli(3,   9, 0.5), 6)}')
print(f'\t  5 успехов из  8 = {round(bernulli( 5,  8, 0.5), 6)}')
print(f'\t 13 успехов из 20 = {round(bernulli(13, 20, 0.5), 6)}')
# Out:
# Вероятность выпадения комбинаций:
# 	  3 успехов из  9 = 0.164062
# 	  5 успехов из  8 = 0.21875
# 	 13 успехов из 20 = 0.073929

# %% [markdown]
# ### 4. Задание
# Из урока по комбинаторике повторите расчеты, сгенерировав возможные варианты перестановок для других значений n и k

# %%
print(f'Сочетания  4-х  элементов из 6-ти  = {combinations(4, 6)}')
print(f'Сочетания 11-ти элементов из 17-ти = {combinations(11, 17)}')
print()

print(f'Размещения  2-х элементов из 5-ми = {arrangements(2, 5)}')
print(f'Размещения  3-х элементов из 7-ми = {arrangements(3, 7)}')
print()

print(f'Перестановка 7-ми элементов = {permutations(7)}')
print(f'Перестановка 8-ми элементов = {permutations(8)}')
# Out:
# Сочетания  4-х  элементов из 6-ти  = 15
# Сочетания 11-ти элементов из 17-ти = 12376
#
# Размещения  2-х элементов из 5-ми = 20
# Размещения  3-х элементов из 7-ми = 210
#
# Перестановка 7-ми элементов = 5040
# Перестановка 8-ми элементов = 40320

# %% [markdown]
# ### 5. Задание
# Дополните код расчетом коэффициента корреляции x и y по формуле:

# %% [markdown]
# $$R = \frac{\sum(x_i - x_m) \cdot (y_i - y_m)}{\sqrt{{\sum(x_i - x_m)^2} \cdot {\sum(y_i - y_m)^2}}} $$

# %%
n = 100
r = 0.7
x = np.random.rand(n)
y = r*x + (1 - r)*np.random.rand(n)
plt.plot(x, y, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

a = (np.sum(x)*np.sum(y) - n*np.sum(x*y))/(np.sum(x)*np.sum(x) - n*np.sum(x*x))
b = (np.sum(y) - a*np.sum(x))/n

A = np.vstack([x, np.ones(len(x))]).T
a1, b1 = np.linalg.lstsq(A, y)[0]
print(a, b)
print(a1, b1)
plt.plot([0, 1], [b, a + b])
plt.show()
# Out:
# 0.7698961782405632 0.10612522761420258
# 0.7698961782405644 0.10612522761420184

# %%
# Коэффициент корреляции (функция numpy)
c = np.corrcoef(x, y) 
c
# Out:
# array([[1.        , 0.93793193],
#        [0.93793193, 1.        ]])

# %%
# Коэффициент корреляции (ручная формула)
coef_corr = np.sum( (x - x.mean())*(y - y.mean()) ) / np.sqrt(np.sum( (x - x.mean())**2) * np.sum((y - y.mean())**2) )
print(f'Коэффициент корреляции по формуле = {round(coef_corr, 10)}')
# Out:
# Коэффициент корреляции по формуле = 0.9379319321
